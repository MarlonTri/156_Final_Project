# %% [markdown]
# ## OSKAR'S CODE

# %% [markdown]
# Results:
# 20-80 split, 500 epochs:
#
# *   Sydney:
#   *   penalty_weight = 0: 5.77% validation error, 0.065% "penalty error"

# %%
import sys
import csv
import numpy as np
import matplotlib.pyplot as plt
import time
import tensorflow as tf
#from tensorflow import keras
import keras
from keras import layers, models, regularizers, backend, utils
import keras.backend.tensorflow_backend as tfback
from IPython.display import display, clear_output
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Linking Dataset from Google Drive

# %%
tf.test.gpu_device_name()
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Read Data

# %%
files = ["/notebooks/WECs_DataSet/Sydney_Data.csv"]
csvfile = open(files[0])
reader = csv.reader(csvfile, delimiter = ',')
rows = [[float(v) for v in row] for row in reader]
rows = np.asarray(rows, dtype='float32')

# %% [markdown]
# *val_ratio* is the ratio of dataset that is used for validation

# %%
Xs = rows[:,0:32]
ys = rows[:,32:49]
val_ratio = 0.2
N = Xs.shape[0]
Xs_train = Xs[0:int((1-val_ratio)*N)]
ys_train = ys[0:int((1-val_ratio)*N)]
Xs_val = Xs[int((1-val_ratio)*N):]
ys_val = ys[int((1-val_ratio)*N):]
print(Xs_train.shape,ys_train.shape)
print(ys_val.shape,ys_val.shape)
# Out:
# (57600, 32) (57600, 17)
# (14400, 17) (14400, 17)

# %%
K = keras.backend

hyperparamter_penalty_weight = 0.1

def custom_loss(y_true,y_pred):
  return K.mean(K.square(y_pred - y_true), axis=-1) + hyperparamter_penalty_weight * K.mean(K.square(K.sum(y_pred[:,0:16], axis=1) - y_pred[:,16]), axis=-1)

def penalty(y_true,y_pred):
  return 100*K.mean(K.abs(K.sum(y_pred[:,0:16], axis=1) - y_pred[:,16])/K.abs(y_pred[:,16]), axis=-1)

inputs = layers.Input(shape=(32,))
d1 = layers.Dense(128, activation = 'relu')(inputs)
d2 = layers.Dense(128, activation = 'relu')(d1)
d3 = layers.Dense(128, activation = 'relu')(d2)
outputs = layers.Dense(17, activation = 'linear')(d3)

simple_model = models.Model(inputs = inputs, outputs = outputs)
simple_model.compile('adam', custom_loss, metrics=['mean_absolute_percentage_error'])
simple_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 17)                2193
# =================================================================
# Total params: 39,441
# Trainable params: 39,441
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs = None):
        clear_output()

loss_hist = simple_model.fit(Xs_train, ys_train, epochs = 100, validation_data = (Xs_val, ys_val), batch_size=8000)
# Out:
# Train on 57600 samples, validate on 14400 samples
# Epoch 1/1000
# 57600/57600 [==============================] - 0s 7us/step - loss: 138620029610.6667 - mean_absolute_percentage_error: 99.9579 - val_loss: 135627894328.8889 - val_mean_absolute_percentage_error: 99.8492
# Epoch 2/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 138258137998.2222 - mean_absolute_percentage_error: 99.6819 - val_loss: 134967985948.4444 - val_mean_absolute_percentage_error: 99.1951
# Epoch 3/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 137223796280.8889 - mean_absolute_percentage_error: 98.5038 - val_loss: 133140576483.5556 - val_mean_absolute_percentage_error: 96.6323
# Epoch 4/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 134697010517.3333 - mean_absolute_percentage_error: 94.6289 - val_loss: 129323853596.4444 - val_mean_absolute_percentage_error: 90.9195
# Epoch 5/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 129439210154.6667 - mean_absolute_percentage_error: 89.3402 - val_loss: 120783592561.7778 - val_mean_absolute_percentage_error: 86.7538
# Epoch 6/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 117821905806.2222 - mean_absolute_percentage_error: 86.9237 - val_loss: 103897553123.5556 - val_mean_absolute_percentage_error: 86.8997
# Epoch 7/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 97225193016.8889 - mean_absolute_percentage_error: 82.7572 - val_loss: 76533731783.1111 - val_mean_absolute_percentage_error: 69.5239
# Epoch 8/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 65619844209.7778 - mean_absolute_percentage_error: 65.5677 - val_loss: 39658636174.2222 - val_mean_absolute_percentage_error: 54.1732
# Epoch 9/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 27919904227.5556 - mean_absolute_percentage_error: 43.5341 - val_loss: 7202545550.2222 - val_mean_absolute_percentage_error: 22.1706
# Epoch 10/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 3339031898.6667 - mean_absolute_percentage_error: 14.5948 - val_loss: 3251388472.8889 - val_mean_absolute_percentage_error: 17.6239
# Epoch 11/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 3806965226.6667 - mean_absolute_percentage_error: 17.6524 - val_loss: 5886498360.8889 - val_mean_absolute_percentage_error: 19.7964
# Epoch 12/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 2468953162.6667 - mean_absolute_percentage_error: 12.6745 - val_loss: 1449491541.3333 - val_mean_absolute_percentage_error: 11.1424
# Epoch 13/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 870267230.2222 - mean_absolute_percentage_error: 8.7440 - val_loss: 1101427925.3333 - val_mean_absolute_percentage_error: 9.2075
# Epoch 14/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 1151012632.8889 - mean_absolute_percentage_error: 8.9449 - val_loss: 1036767608.8889 - val_mean_absolute_percentage_error: 9.2260
# Epoch 15/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 830611758.2222 - mean_absolute_percentage_error: 8.0514 - val_loss: 1186820615.1111 - val_mean_absolute_percentage_error: 9.5018
# Epoch 16/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 770540567.1111 - mean_absolute_percentage_error: 7.8757 - val_loss: 1370044984.8889 - val_mean_absolute_percentage_error: 10.0327
# Epoch 17/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 773383891.5556 - mean_absolute_percentage_error: 7.8788 - val_loss: 1200323413.3333 - val_mean_absolute_percentage_error: 9.5446
# Epoch 18/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 740162739.5556 - mean_absolute_percentage_error: 7.7337 - val_loss: 1096731100.4444 - val_mean_absolute_percentage_error: 9.2541
# Epoch 19/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 742494618.6667 - mean_absolute_percentage_error: 7.7231 - val_loss: 1111100650.6667 - val_mean_absolute_percentage_error: 9.2985
# Epoch 20/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 735499624.8889 - mean_absolute_percentage_error: 7.7145 - val_loss: 1166096213.3333 - val_mean_absolute_percentage_error: 9.4512
# Epoch 21/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 734235066.6667 - mean_absolute_percentage_error: 7.7167 - val_loss: 1160939107.5556 - val_mean_absolute_percentage_error: 9.4299
# Epoch 22/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 731573491.5556 - mean_absolute_percentage_error: 7.7024 - val_loss: 1133999473.7778 - val_mean_absolute_percentage_error: 9.3485
# Epoch 23/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 729629216.0000 - mean_absolute_percentage_error: 7.6922 - val_loss: 1130563278.2222 - val_mean_absolute_percentage_error: 9.3392
# Epoch 24/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 727587822.2222 - mean_absolute_percentage_error: 7.6873 - val_loss: 1140671722.6667 - val_mean_absolute_percentage_error: 9.3711
# Epoch 25/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 725572423.1111 - mean_absolute_percentage_error: 7.6820 - val_loss: 1139878478.2222 - val_mean_absolute_percentage_error: 9.3741
# Epoch 26/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 723584334.2222 - mean_absolute_percentage_error: 7.6760 - val_loss: 1134179612.4444 - val_mean_absolute_percentage_error: 9.3579
# Epoch 27/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 721510618.6667 - mean_absolute_percentage_error: 7.6677 - val_loss: 1129976483.5556 - val_mean_absolute_percentage_error: 9.3449
# Epoch 28/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 719606467.5556 - mean_absolute_percentage_error: 7.6619 - val_loss: 1130170958.2222 - val_mean_absolute_percentage_error: 9.3475
# Epoch 29/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 717791927.1111 - mean_absolute_percentage_error: 7.6554 - val_loss: 1123780216.8889 - val_mean_absolute_percentage_error: 9.3228
# Epoch 30/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 716002170.6667 - mean_absolute_percentage_error: 7.6488 - val_loss: 1125090496.0000 - val_mean_absolute_percentage_error: 9.3281
# Epoch 31/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 714379400.8889 - mean_absolute_percentage_error: 7.6451 - val_loss: 1123931249.7778 - val_mean_absolute_percentage_error: 9.3245
# Epoch 32/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 712826855.1111 - mean_absolute_percentage_error: 7.6406 - val_loss: 1119168291.5556 - val_mean_absolute_percentage_error: 9.3076
# Epoch 33/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 711431866.6667 - mean_absolute_percentage_error: 7.6339 - val_loss: 1114091847.1111 - val_mean_absolute_percentage_error: 9.2836
# Epoch 34/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 710021856.0000 - mean_absolute_percentage_error: 7.6295 - val_loss: 1114898332.4444 - val_mean_absolute_percentage_error: 9.2828
# Epoch 35/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 708747392.0000 - mean_absolute_percentage_error: 7.6265 - val_loss: 1110933895.1111 - val_mean_absolute_percentage_error: 9.2770
# Epoch 36/1000
# 57600/57600 [==============================] - ETA: 0s - loss: 707602282.6667 - mean_absolute_percentage_error: 7.61 - 0s 2us/step - loss: 707563192.8889 - mean_absolute_percentage_error: 7.6222 - val_loss: 1111707889.7778 - val_mean_absolute_percentage_error: 9.2802
# Epoch 37/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 706448311.1111 - mean_absolute_percentage_error: 7.6200 - val_loss: 1108664156.4444 - val_mean_absolute_percentage_error: 9.2779
# Epoch 38/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 705398083.5556 - mean_absolute_percentage_error: 7.6161 - val_loss: 1107209123.5556 - val_mean_absolute_percentage_error: 9.2695
# Epoch 39/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 704471041.7778 - mean_absolute_percentage_error: 7.6141 - val_loss: 1107259427.5556 - val_mean_absolute_percentage_error: 9.2628
# Epoch 40/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 703595777.7778 - mean_absolute_percentage_error: 7.6099 - val_loss: 1101839196.4444 - val_mean_absolute_percentage_error: 9.2594
# Epoch 41/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 702691015.1111 - mean_absolute_percentage_error: 7.6086 - val_loss: 1107055054.2222 - val_mean_absolute_percentage_error: 9.2691
# Epoch 42/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 701856188.4444 - mean_absolute_percentage_error: 7.6060 - val_loss: 1098239808.0000 - val_mean_absolute_percentage_error: 9.2435
# Epoch 43/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 701122282.6667 - mean_absolute_percentage_error: 7.6019 - val_loss: 1099025749.3333 - val_mean_absolute_percentage_error: 9.2458
# Epoch 44/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 700340968.8889 - mean_absolute_percentage_error: 7.6018 - val_loss: 1101147000.8889 - val_mean_absolute_percentage_error: 9.2498
# Epoch 45/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 699621329.7778 - mean_absolute_percentage_error: 7.5993 - val_loss: 1094433038.2222 - val_mean_absolute_percentage_error: 9.2385
# Epoch 46/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 698904723.5556 - mean_absolute_percentage_error: 7.5973 - val_loss: 1098120064.0000 - val_mean_absolute_percentage_error: 9.2410
# Epoch 47/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 698189546.6667 - mean_absolute_percentage_error: 7.5954 - val_loss: 1093367352.8889 - val_mean_absolute_percentage_error: 9.2321
# Epoch 48/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 697562078.2222 - mean_absolute_percentage_error: 7.5921 - val_loss: 1092321009.7778 - val_mean_absolute_percentage_error: 9.2293
# Epoch 49/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 696953456.0000 - mean_absolute_percentage_error: 7.5930 - val_loss: 1095500266.6667 - val_mean_absolute_percentage_error: 9.2366
# Epoch 50/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 696175324.4444 - mean_absolute_percentage_error: 7.5888 - val_loss: 1088492444.4444 - val_mean_absolute_percentage_error: 9.2231
# Epoch 51/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 695583504.0000 - mean_absolute_percentage_error: 7.5870 - val_loss: 1092527672.8889 - val_mean_absolute_percentage_error: 9.2281
# Epoch 52/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 694958705.7778 - mean_absolute_percentage_error: 7.5877 - val_loss: 1092215594.6667 - val_mean_absolute_percentage_error: 9.2361
# Epoch 53/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 694273653.3333 - mean_absolute_percentage_error: 7.5847 - val_loss: 1087984277.3333 - val_mean_absolute_percentage_error: 9.2142
# Epoch 54/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 693620913.7778 - mean_absolute_percentage_error: 7.5829 - val_loss: 1088979911.1111 - val_mean_absolute_percentage_error: 9.2308
# Epoch 55/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 692969639.1111 - mean_absolute_percentage_error: 7.5808 - val_loss: 1086652828.4444 - val_mean_absolute_percentage_error: 9.2091
# Epoch 56/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 692306625.7778 - mean_absolute_percentage_error: 7.5782 - val_loss: 1085551075.5556 - val_mean_absolute_percentage_error: 9.2110
# Epoch 57/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 691606250.6667 - mean_absolute_percentage_error: 7.5776 - val_loss: 1086581432.8889 - val_mean_absolute_percentage_error: 9.2227
# Epoch 58/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 690921406.2222 - mean_absolute_percentage_error: 7.5750 - val_loss: 1082604167.1111 - val_mean_absolute_percentage_error: 9.2016
# Epoch 59/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 690156357.3333 - mean_absolute_percentage_error: 7.5724 - val_loss: 1084273799.1111 - val_mean_absolute_percentage_error: 9.2140
# Epoch 60/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 689410346.6667 - mean_absolute_percentage_error: 7.5715 - val_loss: 1082925617.7778 - val_mean_absolute_percentage_error: 9.2128
# Epoch 61/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 688615287.1111 - mean_absolute_percentage_error: 7.5685 - val_loss: 1081065763.5556 - val_mean_absolute_percentage_error: 9.2025
# Epoch 62/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 687815080.8889 - mean_absolute_percentage_error: 7.5680 - val_loss: 1082730048.0000 - val_mean_absolute_percentage_error: 9.2110
# Epoch 63/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 687041884.4444 - mean_absolute_percentage_error: 7.5660 - val_loss: 1080525297.7778 - val_mean_absolute_percentage_error: 9.2023
# Epoch 64/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 686213585.7778 - mean_absolute_percentage_error: 7.5620 - val_loss: 1078296362.6667 - val_mean_absolute_percentage_error: 9.2100
# Epoch 65/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 685564654.2222 - mean_absolute_percentage_error: 7.5638 - val_loss: 1080839822.2222 - val_mean_absolute_percentage_error: 9.2063
# Epoch 66/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 684758405.3333 - mean_absolute_percentage_error: 7.5559 - val_loss: 1073775260.4444 - val_mean_absolute_percentage_error: 9.1797
# Epoch 67/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 683856876.4444 - mean_absolute_percentage_error: 7.5582 - val_loss: 1081742392.8889 - val_mean_absolute_percentage_error: 9.2022
# Epoch 68/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 682923621.3333 - mean_absolute_percentage_error: 7.5538 - val_loss: 1073409912.8889 - val_mean_absolute_percentage_error: 9.1751
# Epoch 69/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 681985548.4444 - mean_absolute_percentage_error: 7.5505 - val_loss: 1081365212.4444 - val_mean_absolute_percentage_error: 9.2079
# Epoch 70/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 681162350.2222 - mean_absolute_percentage_error: 7.5510 - val_loss: 1073760483.5556 - val_mean_absolute_percentage_error: 9.1905
# Epoch 71/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 680336456.8889 - mean_absolute_percentage_error: 7.5455 - val_loss: 1075152803.5556 - val_mean_absolute_percentage_error: 9.1867
# Epoch 72/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 679548513.7778 - mean_absolute_percentage_error: 7.5465 - val_loss: 1074804117.3333 - val_mean_absolute_percentage_error: 9.1926
# Epoch 73/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 678712750.2222 - mean_absolute_percentage_error: 7.5413 - val_loss: 1072496881.7778 - val_mean_absolute_percentage_error: 9.1913
# Epoch 74/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 677835029.3333 - mean_absolute_percentage_error: 7.5399 - val_loss: 1075710919.1111 - val_mean_absolute_percentage_error: 9.1994
# Epoch 75/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 677002504.8889 - mean_absolute_percentage_error: 7.5389 - val_loss: 1069998890.6667 - val_mean_absolute_percentage_error: 9.1730
# Epoch 76/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 676281237.3333 - mean_absolute_percentage_error: 7.5336 - val_loss: 1072339569.7778 - val_mean_absolute_percentage_error: 9.1798
# Epoch 77/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 675487550.2222 - mean_absolute_percentage_error: 7.5348 - val_loss: 1072586474.6667 - val_mean_absolute_percentage_error: 9.1973
# Epoch 78/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 674739612.4444 - mean_absolute_percentage_error: 7.5303 - val_loss: 1069869596.4444 - val_mean_absolute_percentage_error: 9.1790
# Epoch 79/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 673767344.0000 - mean_absolute_percentage_error: 7.5290 - val_loss: 1074649799.1111 - val_mean_absolute_percentage_error: 9.1891
# Epoch 80/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 672976760.8889 - mean_absolute_percentage_error: 7.5268 - val_loss: 1070574336.0000 - val_mean_absolute_percentage_error: 9.1889
# Epoch 81/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 672155799.1111 - mean_absolute_percentage_error: 7.5241 - val_loss: 1072182663.1111 - val_mean_absolute_percentage_error: 9.1905
# Epoch 82/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 671419736.8889 - mean_absolute_percentage_error: 7.5236 - val_loss: 1071316913.7778 - val_mean_absolute_percentage_error: 9.1820
# Epoch 83/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 670662149.3333 - mean_absolute_percentage_error: 7.5175 - val_loss: 1068297678.2222 - val_mean_absolute_percentage_error: 9.1812
# Epoch 84/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 669888328.8889 - mean_absolute_percentage_error: 7.5192 - val_loss: 1070766584.8889 - val_mean_absolute_percentage_error: 9.1832
# Epoch 85/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 669119955.5556 - mean_absolute_percentage_error: 7.5141 - val_loss: 1068507249.7778 - val_mean_absolute_percentage_error: 9.1898
# Epoch 86/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 668506730.6667 - mean_absolute_percentage_error: 7.5163 - val_loss: 1069275932.4444 - val_mean_absolute_percentage_error: 9.1813
# Epoch 87/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 667676400.0000 - mean_absolute_percentage_error: 7.5102 - val_loss: 1066518897.7778 - val_mean_absolute_percentage_error: 9.1804
# Epoch 88/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 667058796.4444 - mean_absolute_percentage_error: 7.5097 - val_loss: 1069353706.6667 - val_mean_absolute_percentage_error: 9.1908
# Epoch 89/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 666433672.8889 - mean_absolute_percentage_error: 7.5094 - val_loss: 1068088256.0000 - val_mean_absolute_percentage_error: 9.2136
# Epoch 90/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 669118936.8889 - mean_absolute_percentage_error: 7.5137 - val_loss: 1079137301.3333 - val_mean_absolute_percentage_error: 9.3068
# Epoch 91/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 668331041.7778 - mean_absolute_percentage_error: 7.5123 - val_loss: 1065182243.5556 - val_mean_absolute_percentage_error: 9.1217
# Epoch 92/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 665480088.8889 - mean_absolute_percentage_error: 7.5022 - val_loss: 1065297941.3333 - val_mean_absolute_percentage_error: 9.1979
# Epoch 93/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 664043905.7778 - mean_absolute_percentage_error: 7.5006 - val_loss: 1066296924.4444 - val_mean_absolute_percentage_error: 9.1621
# Epoch 94/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 664146928.0000 - mean_absolute_percentage_error: 7.4992 - val_loss: 1065658552.8889 - val_mean_absolute_percentage_error: 9.1491
# Epoch 95/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 663004408.8889 - mean_absolute_percentage_error: 7.4995 - val_loss: 1065886115.5556 - val_mean_absolute_percentage_error: 9.2248
# Epoch 96/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 662770074.6667 - mean_absolute_percentage_error: 7.4952 - val_loss: 1063691427.5556 - val_mean_absolute_percentage_error: 9.1386
# Epoch 97/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 663559690.6667 - mean_absolute_percentage_error: 7.4938 - val_loss: 1063401742.2222 - val_mean_absolute_percentage_error: 9.1490
# Epoch 98/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 661055863.1111 - mean_absolute_percentage_error: 7.4947 - val_loss: 1062844878.2222 - val_mean_absolute_percentage_error: 9.1939
# Epoch 99/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 660276224.0000 - mean_absolute_percentage_error: 7.4874 - val_loss: 1063180423.1111 - val_mean_absolute_percentage_error: 9.1658
# Epoch 100/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 659687676.4444 - mean_absolute_percentage_error: 7.4930 - val_loss: 1060077056.0000 - val_mean_absolute_percentage_error: 9.1707
# Epoch 101/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 659255395.5556 - mean_absolute_percentage_error: 7.4835 - val_loss: 1062729358.2222 - val_mean_absolute_percentage_error: 9.1586
# Epoch 102/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 659495363.5556 - mean_absolute_percentage_error: 7.4894 - val_loss: 1062617016.8889 - val_mean_absolute_percentage_error: 9.1000
# Epoch 103/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 662700839.1111 - mean_absolute_percentage_error: 7.4894 - val_loss: 1057938460.4444 - val_mean_absolute_percentage_error: 9.1122
# Epoch 104/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 658117201.7778 - mean_absolute_percentage_error: 7.4827 - val_loss: 1062778531.5556 - val_mean_absolute_percentage_error: 9.2081
# Epoch 105/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 658010503.1111 - mean_absolute_percentage_error: 7.4860 - val_loss: 1057017905.7778 - val_mean_absolute_percentage_error: 9.1608
# Epoch 106/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 657806362.6667 - mean_absolute_percentage_error: 7.4803 - val_loss: 1060862208.0000 - val_mean_absolute_percentage_error: 9.1079
# Epoch 107/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 657443335.1111 - mean_absolute_percentage_error: 7.4816 - val_loss: 1055246385.7778 - val_mean_absolute_percentage_error: 9.1607
# Epoch 108/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 655956257.7778 - mean_absolute_percentage_error: 7.4772 - val_loss: 1057612337.7778 - val_mean_absolute_percentage_error: 9.1680
# Epoch 109/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 655343660.4444 - mean_absolute_percentage_error: 7.4753 - val_loss: 1057973781.3333 - val_mean_absolute_percentage_error: 9.1511
# Epoch 110/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 654996963.5556 - mean_absolute_percentage_error: 7.4788 - val_loss: 1053703217.7778 - val_mean_absolute_percentage_error: 9.1438
# Epoch 111/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 654654476.4444 - mean_absolute_percentage_error: 7.4710 - val_loss: 1058592064.0000 - val_mean_absolute_percentage_error: 9.1536
# Epoch 112/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 654433555.5556 - mean_absolute_percentage_error: 7.4776 - val_loss: 1054409884.4444 - val_mean_absolute_percentage_error: 9.1123
# Epoch 113/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 656650885.3333 - mean_absolute_percentage_error: 7.4729 - val_loss: 1063739562.6667 - val_mean_absolute_percentage_error: 9.0636
# Epoch 114/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 660870263.1111 - mean_absolute_percentage_error: 7.4832 - val_loss: 1051998044.4444 - val_mean_absolute_percentage_error: 9.1548
# Epoch 115/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 655647688.8889 - mean_absolute_percentage_error: 7.4738 - val_loss: 1057748785.7778 - val_mean_absolute_percentage_error: 9.1637
# Epoch 116/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 653948906.6667 - mean_absolute_percentage_error: 7.4730 - val_loss: 1051354040.8889 - val_mean_absolute_percentage_error: 9.1353
# Epoch 117/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 652649232.0000 - mean_absolute_percentage_error: 7.4694 - val_loss: 1054250908.4444 - val_mean_absolute_percentage_error: 9.1618
# Epoch 118/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 651939164.4444 - mean_absolute_percentage_error: 7.4665 - val_loss: 1051385002.6667 - val_mean_absolute_percentage_error: 9.1349
# Epoch 119/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 651719464.8889 - mean_absolute_percentage_error: 7.4687 - val_loss: 1052289784.8889 - val_mean_absolute_percentage_error: 9.1738
# Epoch 120/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 651328833.7778 - mean_absolute_percentage_error: 7.4648 - val_loss: 1051656974.2222 - val_mean_absolute_percentage_error: 9.1239
# Epoch 121/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 650934087.1111 - mean_absolute_percentage_error: 7.4654 - val_loss: 1052543765.3333 - val_mean_absolute_percentage_error: 9.1752
# Epoch 122/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 650901456.0000 - mean_absolute_percentage_error: 7.4636 - val_loss: 1048150741.3333 - val_mean_absolute_percentage_error: 9.1325
# Epoch 123/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 650605075.5556 - mean_absolute_percentage_error: 7.4615 - val_loss: 1053750236.4444 - val_mean_absolute_percentage_error: 9.1351
# Epoch 124/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 650676522.6667 - mean_absolute_percentage_error: 7.4670 - val_loss: 1045398343.1111 - val_mean_absolute_percentage_error: 9.1737
# Epoch 125/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 651262296.8889 - mean_absolute_percentage_error: 7.4585 - val_loss: 1051539811.5556 - val_mean_absolute_percentage_error: 9.1604
# Epoch 126/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 649324289.7778 - mean_absolute_percentage_error: 7.4615 - val_loss: 1047857678.2222 - val_mean_absolute_percentage_error: 9.1378
# Epoch 127/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 649125639.1111 - mean_absolute_percentage_error: 7.4559 - val_loss: 1052349888.0000 - val_mean_absolute_percentage_error: 9.1652
# Epoch 128/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 649057742.2222 - mean_absolute_percentage_error: 7.4635 - val_loss: 1043625201.7778 - val_mean_absolute_percentage_error: 9.1415
# Epoch 129/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 649507968.0000 - mean_absolute_percentage_error: 7.4549 - val_loss: 1057439552.0000 - val_mean_absolute_percentage_error: 9.2098
# Epoch 130/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 655742245.3333 - mean_absolute_percentage_error: 7.4769 - val_loss: 1060854513.7778 - val_mean_absolute_percentage_error: 9.2774
# Epoch 131/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 653796913.7778 - mean_absolute_percentage_error: 7.4648 - val_loss: 1054139050.6667 - val_mean_absolute_percentage_error: 9.0569
# Epoch 132/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 650073340.4444 - mean_absolute_percentage_error: 7.4578 - val_loss: 1049206826.6667 - val_mean_absolute_percentage_error: 9.1771
# Epoch 133/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 647935905.7778 - mean_absolute_percentage_error: 7.4570 - val_loss: 1043157205.3333 - val_mean_absolute_percentage_error: 9.1127
# Epoch 134/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 647206819.5556 - mean_absolute_percentage_error: 7.4511 - val_loss: 1046668003.5556 - val_mean_absolute_percentage_error: 9.1359
# Epoch 135/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 646898149.3333 - mean_absolute_percentage_error: 7.4548 - val_loss: 1042175111.1111 - val_mean_absolute_percentage_error: 9.1183
# Epoch 136/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 646674003.5556 - mean_absolute_percentage_error: 7.4496 - val_loss: 1042876664.8889 - val_mean_absolute_percentage_error: 9.1118
# Epoch 137/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 646544362.6667 - mean_absolute_percentage_error: 7.4494 - val_loss: 1042622222.2222 - val_mean_absolute_percentage_error: 9.1223
# Epoch 138/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 646304293.3333 - mean_absolute_percentage_error: 7.4501 - val_loss: 1044303566.2222 - val_mean_absolute_percentage_error: 9.1044
# Epoch 139/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 646165104.0000 - mean_absolute_percentage_error: 7.4507 - val_loss: 1041442773.3333 - val_mean_absolute_percentage_error: 9.1352
# Epoch 140/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 647334090.6667 - mean_absolute_percentage_error: 7.4539 - val_loss: 1044602360.8889 - val_mean_absolute_percentage_error: 9.1603
# Epoch 141/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 645843176.8889 - mean_absolute_percentage_error: 7.4486 - val_loss: 1044336327.1111 - val_mean_absolute_percentage_error: 9.0980
# Epoch 142/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 645512318.2222 - mean_absolute_percentage_error: 7.4499 - val_loss: 1040661781.3333 - val_mean_absolute_percentage_error: 9.1357
# Epoch 143/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 646394826.6667 - mean_absolute_percentage_error: 7.4524 - val_loss: 1040030599.1111 - val_mean_absolute_percentage_error: 9.1518
# Epoch 144/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 645164455.1111 - mean_absolute_percentage_error: 7.4460 - val_loss: 1040880014.2222 - val_mean_absolute_percentage_error: 9.1011
# Epoch 145/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 644655841.7778 - mean_absolute_percentage_error: 7.4469 - val_loss: 1040210439.1111 - val_mean_absolute_percentage_error: 9.1409
# Epoch 146/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 645353191.1111 - mean_absolute_percentage_error: 7.4462 - val_loss: 1040867797.3333 - val_mean_absolute_percentage_error: 9.1557
# Epoch 147/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 644863377.7778 - mean_absolute_percentage_error: 7.4466 - val_loss: 1034845525.3333 - val_mean_absolute_percentage_error: 9.0757
# Epoch 148/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 647049335.1111 - mean_absolute_percentage_error: 7.4435 - val_loss: 1045602545.7778 - val_mean_absolute_percentage_error: 9.0579
# Epoch 149/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 645168935.1111 - mean_absolute_percentage_error: 7.4501 - val_loss: 1033350094.2222 - val_mean_absolute_percentage_error: 9.1330
# Epoch 150/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 645248376.8889 - mean_absolute_percentage_error: 7.4435 - val_loss: 1039423047.1111 - val_mean_absolute_percentage_error: 9.1281
# Epoch 151/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 643642588.4444 - mean_absolute_percentage_error: 7.4427 - val_loss: 1032536455.1111 - val_mean_absolute_percentage_error: 9.0494
# Epoch 152/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 644274929.7778 - mean_absolute_percentage_error: 7.4412 - val_loss: 1035594581.3333 - val_mean_absolute_percentage_error: 9.0902
# Epoch 153/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642928832.0000 - mean_absolute_percentage_error: 7.4383 - val_loss: 1032484771.5556 - val_mean_absolute_percentage_error: 9.0767
# Epoch 154/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642884213.3333 - mean_absolute_percentage_error: 7.4404 - val_loss: 1033730894.2222 - val_mean_absolute_percentage_error: 9.0934
# Epoch 155/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642706791.1111 - mean_absolute_percentage_error: 7.4424 - val_loss: 1031450595.5556 - val_mean_absolute_percentage_error: 9.1194
# Epoch 156/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642866856.8889 - mean_absolute_percentage_error: 7.4380 - val_loss: 1032806869.3333 - val_mean_absolute_percentage_error: 9.1038
# Epoch 157/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642208304.0000 - mean_absolute_percentage_error: 7.4400 - val_loss: 1030696000.0000 - val_mean_absolute_percentage_error: 9.1127
# Epoch 158/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 644968453.3333 - mean_absolute_percentage_error: 7.4423 - val_loss: 1046727687.1111 - val_mean_absolute_percentage_error: 9.2227
# Epoch 159/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 651244606.2222 - mean_absolute_percentage_error: 7.4601 - val_loss: 1024509411.5556 - val_mean_absolute_percentage_error: 9.0594
# Epoch 160/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 644008481.7778 - mean_absolute_percentage_error: 7.4380 - val_loss: 1035894485.3333 - val_mean_absolute_percentage_error: 9.1158
# Epoch 161/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 643414030.2222 - mean_absolute_percentage_error: 7.4430 - val_loss: 1024253987.5556 - val_mean_absolute_percentage_error: 9.0590
# Epoch 162/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642122803.5556 - mean_absolute_percentage_error: 7.4328 - val_loss: 1033082268.4444 - val_mean_absolute_percentage_error: 9.1085
# Epoch 163/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 641236839.1111 - mean_absolute_percentage_error: 7.4361 - val_loss: 1026994524.4444 - val_mean_absolute_percentage_error: 9.0681
# Epoch 164/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 640650387.5556 - mean_absolute_percentage_error: 7.4355 - val_loss: 1026945571.5556 - val_mean_absolute_percentage_error: 9.0799
# Epoch 165/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 640609456.0000 - mean_absolute_percentage_error: 7.4310 - val_loss: 1031606599.1111 - val_mean_absolute_percentage_error: 9.0955
# Epoch 166/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 640431146.6667 - mean_absolute_percentage_error: 7.4334 - val_loss: 1026918641.7778 - val_mean_absolute_percentage_error: 9.0750
# Epoch 167/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 640308648.8889 - mean_absolute_percentage_error: 7.4323 - val_loss: 1027332778.6667 - val_mean_absolute_percentage_error: 9.0556
# Epoch 168/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 640111671.1111 - mean_absolute_percentage_error: 7.4308 - val_loss: 1024641351.1111 - val_mean_absolute_percentage_error: 9.0693
# Epoch 169/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 640018592.0000 - mean_absolute_percentage_error: 7.4297 - val_loss: 1029858424.8889 - val_mean_absolute_percentage_error: 9.1082
# Epoch 170/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 639779248.0000 - mean_absolute_percentage_error: 7.4314 - val_loss: 1025044771.5556 - val_mean_absolute_percentage_error: 9.0730
# Epoch 171/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 639405219.5556 - mean_absolute_percentage_error: 7.4308 - val_loss: 1023529500.4444 - val_mean_absolute_percentage_error: 9.0721
# Epoch 172/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 639139836.4444 - mean_absolute_percentage_error: 7.4290 - val_loss: 1023345550.2222 - val_mean_absolute_percentage_error: 9.0509
# Epoch 173/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 639339786.6667 - mean_absolute_percentage_error: 7.4276 - val_loss: 1028617073.7778 - val_mean_absolute_percentage_error: 9.0477
# Epoch 174/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 639455957.3333 - mean_absolute_percentage_error: 7.4336 - val_loss: 1018236188.4444 - val_mean_absolute_percentage_error: 9.0242
# Epoch 175/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 639794750.2222 - mean_absolute_percentage_error: 7.4211 - val_loss: 1037766193.7778 - val_mean_absolute_percentage_error: 9.0677
# Epoch 176/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 642882417.7778 - mean_absolute_percentage_error: 7.4414 - val_loss: 1025648824.8889 - val_mean_absolute_percentage_error: 8.9335
# Epoch 177/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 647257571.5556 - mean_absolute_percentage_error: 7.4374 - val_loss: 1033632042.6667 - val_mean_absolute_percentage_error: 9.1443
# Epoch 178/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 641470892.4444 - mean_absolute_percentage_error: 7.4323 - val_loss: 1020305272.8889 - val_mean_absolute_percentage_error: 9.0162
# Epoch 179/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 639320855.1111 - mean_absolute_percentage_error: 7.4270 - val_loss: 1025242986.6667 - val_mean_absolute_percentage_error: 9.0955
# Epoch 180/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 638413841.7778 - mean_absolute_percentage_error: 7.4257 - val_loss: 1021336974.2222 - val_mean_absolute_percentage_error: 9.0435
# Epoch 181/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 637786296.8889 - mean_absolute_percentage_error: 7.4205 - val_loss: 1027306552.8889 - val_mean_absolute_percentage_error: 9.0881
# Epoch 182/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 637442560.0000 - mean_absolute_percentage_error: 7.4247 - val_loss: 1018841144.8889 - val_mean_absolute_percentage_error: 9.0386
# Epoch 183/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 637261372.4444 - mean_absolute_percentage_error: 7.4210 - val_loss: 1025257536.0000 - val_mean_absolute_percentage_error: 9.0769
# Epoch 184/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 637081589.3333 - mean_absolute_percentage_error: 7.4221 - val_loss: 1021963712.0000 - val_mean_absolute_percentage_error: 9.0735
# Epoch 185/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 636726696.8889 - mean_absolute_percentage_error: 7.4226 - val_loss: 1019904071.1111 - val_mean_absolute_percentage_error: 9.0499
# Epoch 186/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 636427889.7778 - mean_absolute_percentage_error: 7.4204 - val_loss: 1020768156.4444 - val_mean_absolute_percentage_error: 9.0598
# Epoch 187/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 636227754.6667 - mean_absolute_percentage_error: 7.4190 - val_loss: 1019355200.0000 - val_mean_absolute_percentage_error: 9.0473
# Epoch 188/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 636086672.0000 - mean_absolute_percentage_error: 7.4184 - val_loss: 1019648512.0000 - val_mean_absolute_percentage_error: 9.0488
# Epoch 189/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 635898800.0000 - mean_absolute_percentage_error: 7.4158 - val_loss: 1020905621.3333 - val_mean_absolute_percentage_error: 9.0646
# Epoch 190/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 635904035.5556 - mean_absolute_percentage_error: 7.4209 - val_loss: 1016221027.5556 - val_mean_absolute_percentage_error: 9.0515
# Epoch 191/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 635556833.7778 - mean_absolute_percentage_error: 7.4166 - val_loss: 1020177180.4444 - val_mean_absolute_percentage_error: 9.0601
# Epoch 192/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 636355027.5556 - mean_absolute_percentage_error: 7.4198 - val_loss: 1024484117.3333 - val_mean_absolute_percentage_error: 9.1320
# Epoch 193/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 647718010.6667 - mean_absolute_percentage_error: 7.4373 - val_loss: 1020199210.6667 - val_mean_absolute_percentage_error: 9.0989
# Epoch 194/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 638843786.6667 - mean_absolute_percentage_error: 7.4201 - val_loss: 1016392917.3333 - val_mean_absolute_percentage_error: 9.0075
# Epoch 195/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 636620318.2222 - mean_absolute_percentage_error: 7.4165 - val_loss: 1016874616.8889 - val_mean_absolute_percentage_error: 9.0519
# Epoch 196/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 635397639.1111 - mean_absolute_percentage_error: 7.4149 - val_loss: 1016331825.7778 - val_mean_absolute_percentage_error: 9.0489
# Epoch 197/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 634772583.1111 - mean_absolute_percentage_error: 7.4121 - val_loss: 1017904554.6667 - val_mean_absolute_percentage_error: 9.0251
# Epoch 198/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 634443102.2222 - mean_absolute_percentage_error: 7.4132 - val_loss: 1013980259.5556 - val_mean_absolute_percentage_error: 9.0529
# Epoch 199/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 634202938.6667 - mean_absolute_percentage_error: 7.4112 - val_loss: 1019671822.2222 - val_mean_absolute_percentage_error: 9.0444
# Epoch 200/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 633736181.3333 - mean_absolute_percentage_error: 7.4129 - val_loss: 1006059790.2222 - val_mean_absolute_percentage_error: 8.9972
# Epoch 201/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 633825381.3333 - mean_absolute_percentage_error: 7.4083 - val_loss: 1018195235.5556 - val_mean_absolute_percentage_error: 9.0416
# Epoch 202/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 633330620.4444 - mean_absolute_percentage_error: 7.4087 - val_loss: 1009781440.0000 - val_mean_absolute_percentage_error: 9.0262
# Epoch 203/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 633090078.2222 - mean_absolute_percentage_error: 7.4096 - val_loss: 1011178616.8889 - val_mean_absolute_percentage_error: 9.0081
# Epoch 204/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 632812426.6667 - mean_absolute_percentage_error: 7.4064 - val_loss: 1010690403.5556 - val_mean_absolute_percentage_error: 9.0263
# Epoch 205/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 632525934.2222 - mean_absolute_percentage_error: 7.4061 - val_loss: 1011062584.8889 - val_mean_absolute_percentage_error: 9.0253
# Epoch 206/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 632395096.8889 - mean_absolute_percentage_error: 7.4082 - val_loss: 1006905301.3333 - val_mean_absolute_percentage_error: 9.0224
# Epoch 207/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 632363342.2222 - mean_absolute_percentage_error: 7.4036 - val_loss: 1014742755.5556 - val_mean_absolute_percentage_error: 9.0388
# Epoch 208/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 631957256.8889 - mean_absolute_percentage_error: 7.4051 - val_loss: 1010693212.4444 - val_mean_absolute_percentage_error: 9.0120
# Epoch 209/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 631667285.3333 - mean_absolute_percentage_error: 7.4051 - val_loss: 1010436380.4444 - val_mean_absolute_percentage_error: 9.0132
# Epoch 210/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 631502864.0000 - mean_absolute_percentage_error: 7.4016 - val_loss: 1014841194.6667 - val_mean_absolute_percentage_error: 9.0373
# Epoch 211/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 631499308.4444 - mean_absolute_percentage_error: 7.4048 - val_loss: 1010564288.0000 - val_mean_absolute_percentage_error: 9.0551
# Epoch 212/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 638526430.2222 - mean_absolute_percentage_error: 7.4190 - val_loss: 1041535281.7778 - val_mean_absolute_percentage_error: 9.2244
# Epoch 213/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 643271749.3333 - mean_absolute_percentage_error: 7.4219 - val_loss: 1017442915.5556 - val_mean_absolute_percentage_error: 8.9333
# Epoch 214/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 634977690.6667 - mean_absolute_percentage_error: 7.4087 - val_loss: 1008795669.3333 - val_mean_absolute_percentage_error: 9.0514
# Epoch 215/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 632003555.5556 - mean_absolute_percentage_error: 7.3996 - val_loss: 1014061845.3333 - val_mean_absolute_percentage_error: 9.0488
# Epoch 216/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 630960263.1111 - mean_absolute_percentage_error: 7.4013 - val_loss: 1005351808.0000 - val_mean_absolute_percentage_error: 8.9654
# Epoch 217/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 630913201.7778 - mean_absolute_percentage_error: 7.3970 - val_loss: 1010987491.5556 - val_mean_absolute_percentage_error: 9.0479
# Epoch 218/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 629914392.8889 - mean_absolute_percentage_error: 7.3959 - val_loss: 1008808490.6667 - val_mean_absolute_percentage_error: 9.0141
# Epoch 219/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 629600808.8889 - mean_absolute_percentage_error: 7.3981 - val_loss: 1007936618.6667 - val_mean_absolute_percentage_error: 9.0088
# Epoch 220/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 629268668.4444 - mean_absolute_percentage_error: 7.3936 - val_loss: 1010298232.8889 - val_mean_absolute_percentage_error: 9.0341
# Epoch 221/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 629012234.6667 - mean_absolute_percentage_error: 7.3964 - val_loss: 1003064184.8889 - val_mean_absolute_percentage_error: 8.9917
# Epoch 222/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 628648350.2222 - mean_absolute_percentage_error: 7.3926 - val_loss: 1010304476.4444 - val_mean_absolute_percentage_error: 9.0336
# Epoch 223/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 628388069.3333 - mean_absolute_percentage_error: 7.3943 - val_loss: 1003286343.1111 - val_mean_absolute_percentage_error: 8.9827
# Epoch 224/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 628320078.2222 - mean_absolute_percentage_error: 7.3892 - val_loss: 1009586801.7778 - val_mean_absolute_percentage_error: 9.0245
# Epoch 225/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 628059544.8889 - mean_absolute_percentage_error: 7.3951 - val_loss: 1002602560.0000 - val_mean_absolute_percentage_error: 9.0027
# Epoch 226/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 627660339.5556 - mean_absolute_percentage_error: 7.3911 - val_loss: 1004509653.3333 - val_mean_absolute_percentage_error: 8.9990
# Epoch 227/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 627387345.7778 - mean_absolute_percentage_error: 7.3890 - val_loss: 1007090538.6667 - val_mean_absolute_percentage_error: 9.0159
# Epoch 228/1000
# ...
# Epoch 925/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 287231936.0000 - mean_absolute_percentage_error: 5.1940 - val_loss: 641712924.4444 - val_mean_absolute_percentage_error: 7.6299
# Epoch 926/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 286879900.4444 - mean_absolute_percentage_error: 5.1856 - val_loss: 644298730.6667 - val_mean_absolute_percentage_error: 7.6410
# Epoch 927/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 286207176.0000 - mean_absolute_percentage_error: 5.1787 - val_loss: 652007146.6667 - val_mean_absolute_percentage_error: 7.6681
# Epoch 928/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 285739707.5556 - mean_absolute_percentage_error: 5.1770 - val_loss: 653626737.7778 - val_mean_absolute_percentage_error: 7.6840
# Epoch 929/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 285726417.7778 - mean_absolute_percentage_error: 5.1766 - val_loss: 655995733.3333 - val_mean_absolute_percentage_error: 7.7208
# Epoch 930/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 289570187.5556 - mean_absolute_percentage_error: 5.1876 - val_loss: 686906012.4444 - val_mean_absolute_percentage_error: 7.9203
# Epoch 931/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 289891723.1111 - mean_absolute_percentage_error: 5.1891 - val_loss: 668368156.4444 - val_mean_absolute_percentage_error: 7.6647
# Epoch 932/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 286158231.5556 - mean_absolute_percentage_error: 5.1719 - val_loss: 650294478.2222 - val_mean_absolute_percentage_error: 7.6531
# Epoch 933/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 285053304.8889 - mean_absolute_percentage_error: 5.1701 - val_loss: 645551530.6667 - val_mean_absolute_percentage_error: 7.6216
# Epoch 934/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 284329381.3333 - mean_absolute_percentage_error: 5.1585 - val_loss: 653788636.4444 - val_mean_absolute_percentage_error: 7.6471
# Epoch 935/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 283743862.2222 - mean_absolute_percentage_error: 5.1548 - val_loss: 666964010.6667 - val_mean_absolute_percentage_error: 7.7251
# Epoch 936/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 283215837.3333 - mean_absolute_percentage_error: 5.1539 - val_loss: 668255559.1111 - val_mean_absolute_percentage_error: 7.7159
# Epoch 937/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 283329280.8889 - mean_absolute_percentage_error: 5.1549 - val_loss: 658605169.7778 - val_mean_absolute_percentage_error: 7.6764
# Epoch 938/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 283073299.5556 - mean_absolute_percentage_error: 5.1510 - val_loss: 693199623.1111 - val_mean_absolute_percentage_error: 7.8173
# Epoch 939/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 284856296.8889 - mean_absolute_percentage_error: 5.1619 - val_loss: 677396501.3333 - val_mean_absolute_percentage_error: 7.7591
# Epoch 940/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 283368652.4444 - mean_absolute_percentage_error: 5.1534 - val_loss: 659935182.2222 - val_mean_absolute_percentage_error: 7.6674
# Epoch 941/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 281737016.0000 - mean_absolute_percentage_error: 5.1410 - val_loss: 662170709.3333 - val_mean_absolute_percentage_error: 7.6817
# Epoch 942/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 281310463.1111 - mean_absolute_percentage_error: 5.1348 - val_loss: 672842965.3333 - val_mean_absolute_percentage_error: 7.7336
# Epoch 943/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 281275479.1111 - mean_absolute_percentage_error: 5.1329 - val_loss: 650410908.4444 - val_mean_absolute_percentage_error: 7.6406
# Epoch 944/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 282128726.6667 - mean_absolute_percentage_error: 5.1359 - val_loss: 655730353.7778 - val_mean_absolute_percentage_error: 7.6629
# Epoch 945/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 280991982.2222 - mean_absolute_percentage_error: 5.1270 - val_loss: 650235683.5556 - val_mean_absolute_percentage_error: 7.6527
# Epoch 946/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 280432885.7778 - mean_absolute_percentage_error: 5.1231 - val_loss: 660403797.3333 - val_mean_absolute_percentage_error: 7.7051
# Epoch 947/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 281386825.7778 - mean_absolute_percentage_error: 5.1284 - val_loss: 658578773.3333 - val_mean_absolute_percentage_error: 7.7421
# Epoch 948/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 286264687.1111 - mean_absolute_percentage_error: 5.1366 - val_loss: 651382691.5556 - val_mean_absolute_percentage_error: 7.6966
# Epoch 949/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 280605728.8889 - mean_absolute_percentage_error: 5.1207 - val_loss: 652961258.6667 - val_mean_absolute_percentage_error: 7.5703
# Epoch 950/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 280445840.4444 - mean_absolute_percentage_error: 5.1190 - val_loss: 657748657.7778 - val_mean_absolute_percentage_error: 7.6995
# Epoch 951/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 279464705.7778 - mean_absolute_percentage_error: 5.1107 - val_loss: 656633322.6667 - val_mean_absolute_percentage_error: 7.6330
# Epoch 952/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 278994333.3333 - mean_absolute_percentage_error: 5.1061 - val_loss: 670313763.5556 - val_mean_absolute_percentage_error: 7.7039
# Epoch 953/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 279126574.2222 - mean_absolute_percentage_error: 5.1100 - val_loss: 660797233.7778 - val_mean_absolute_percentage_error: 7.6856
# Epoch 954/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 279129783.1111 - mean_absolute_percentage_error: 5.1143 - val_loss: 637131313.7778 - val_mean_absolute_percentage_error: 7.5497
# Epoch 955/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 278814796.0000 - mean_absolute_percentage_error: 5.1059 - val_loss: 655348586.6667 - val_mean_absolute_percentage_error: 7.6535
# Epoch 956/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 277981216.0000 - mean_absolute_percentage_error: 5.1017 - val_loss: 645909809.7778 - val_mean_absolute_percentage_error: 7.6087
# Epoch 957/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 278024072.8889 - mean_absolute_percentage_error: 5.1011 - val_loss: 637383772.4444 - val_mean_absolute_percentage_error: 7.5557
# Epoch 958/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 277380885.3333 - mean_absolute_percentage_error: 5.0921 - val_loss: 647547150.2222 - val_mean_absolute_percentage_error: 7.5959
# Epoch 959/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 276517688.8889 - mean_absolute_percentage_error: 5.0868 - val_loss: 646231708.4444 - val_mean_absolute_percentage_error: 7.5900
# Epoch 960/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 276413428.4444 - mean_absolute_percentage_error: 5.0854 - val_loss: 639057749.3333 - val_mean_absolute_percentage_error: 7.5408
# Epoch 961/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 277354249.3333 - mean_absolute_percentage_error: 5.0847 - val_loss: 658604906.6667 - val_mean_absolute_percentage_error: 7.6036
# Epoch 962/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 276694876.4444 - mean_absolute_percentage_error: 5.0807 - val_loss: 647350179.5556 - val_mean_absolute_percentage_error: 7.5554
# Epoch 963/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 277138829.3333 - mean_absolute_percentage_error: 5.0823 - val_loss: 623207459.5556 - val_mean_absolute_percentage_error: 7.4721
# Epoch 964/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 278996839.5556 - mean_absolute_percentage_error: 5.0892 - val_loss: 634762382.2222 - val_mean_absolute_percentage_error: 7.5216
# Epoch 965/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 276850337.3333 - mean_absolute_percentage_error: 5.0739 - val_loss: 634369813.3333 - val_mean_absolute_percentage_error: 7.5113
# Epoch 966/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 276523504.0000 - mean_absolute_percentage_error: 5.0697 - val_loss: 650909319.1111 - val_mean_absolute_percentage_error: 7.5587
# Epoch 967/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 276261636.4444 - mean_absolute_percentage_error: 5.0671 - val_loss: 652256384.0000 - val_mean_absolute_percentage_error: 7.5666
# Epoch 968/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274684064.0000 - mean_absolute_percentage_error: 5.0638 - val_loss: 656910983.1111 - val_mean_absolute_percentage_error: 7.6412
# Epoch 969/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274011214.2222 - mean_absolute_percentage_error: 5.0630 - val_loss: 650126371.5556 - val_mean_absolute_percentage_error: 7.6307
# Epoch 970/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274026512.8889 - mean_absolute_percentage_error: 5.0597 - val_loss: 650621162.6667 - val_mean_absolute_percentage_error: 7.6312
# Epoch 971/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 273946984.0000 - mean_absolute_percentage_error: 5.0600 - val_loss: 644139968.0000 - val_mean_absolute_percentage_error: 7.6258
# Epoch 972/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274481463.5556 - mean_absolute_percentage_error: 5.0589 - val_loss: 633488291.5556 - val_mean_absolute_percentage_error: 7.5891
# Epoch 973/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274988869.3333 - mean_absolute_percentage_error: 5.0588 - val_loss: 655005454.2222 - val_mean_absolute_percentage_error: 7.6751
# Epoch 974/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 273536737.7778 - mean_absolute_percentage_error: 5.0529 - val_loss: 647823708.4444 - val_mean_absolute_percentage_error: 7.6157
# Epoch 975/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 273221137.3333 - mean_absolute_percentage_error: 5.0529 - val_loss: 628915185.7778 - val_mean_absolute_percentage_error: 7.5185
# Epoch 976/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274182604.0000 - mean_absolute_percentage_error: 5.0548 - val_loss: 621950471.1111 - val_mean_absolute_percentage_error: 7.4577
# Epoch 977/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274308120.8889 - mean_absolute_percentage_error: 5.0489 - val_loss: 639256085.3333 - val_mean_absolute_percentage_error: 7.5205
# Epoch 978/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 272436947.5556 - mean_absolute_percentage_error: 5.0362 - val_loss: 638186659.5556 - val_mean_absolute_percentage_error: 7.5199
# Epoch 979/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 272327193.7778 - mean_absolute_percentage_error: 5.0347 - val_loss: 649249237.3333 - val_mean_absolute_percentage_error: 7.5618
# Epoch 980/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 271772300.0000 - mean_absolute_percentage_error: 5.0309 - val_loss: 675521927.1111 - val_mean_absolute_percentage_error: 7.6818
# Epoch 981/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 274152940.4444 - mean_absolute_percentage_error: 5.0435 - val_loss: 674088227.5556 - val_mean_absolute_percentage_error: 7.6916
# Epoch 982/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 271794862.6667 - mean_absolute_percentage_error: 5.0335 - val_loss: 637772615.1111 - val_mean_absolute_percentage_error: 7.5364
# Epoch 983/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 271140215.1111 - mean_absolute_percentage_error: 5.0250 - val_loss: 654845504.0000 - val_mean_absolute_percentage_error: 7.5588
# Epoch 984/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 273127000.4444 - mean_absolute_percentage_error: 5.0293 - val_loss: 653145123.5556 - val_mean_absolute_percentage_error: 7.5053
# Epoch 985/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 273572353.7778 - mean_absolute_percentage_error: 5.0312 - val_loss: 646521457.7778 - val_mean_absolute_percentage_error: 7.5834
# Epoch 986/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 270465406.6667 - mean_absolute_percentage_error: 5.0225 - val_loss: 633798456.8889 - val_mean_absolute_percentage_error: 7.5740
# Epoch 987/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 270050903.1111 - mean_absolute_percentage_error: 5.0175 - val_loss: 631635320.8889 - val_mean_absolute_percentage_error: 7.5058
# Epoch 988/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 270002183.5556 - mean_absolute_percentage_error: 5.0143 - val_loss: 632846976.0000 - val_mean_absolute_percentage_error: 7.5187
# Epoch 989/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 269404661.7778 - mean_absolute_percentage_error: 5.0076 - val_loss: 640434311.1111 - val_mean_absolute_percentage_error: 7.5702
# Epoch 990/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 269051756.8889 - mean_absolute_percentage_error: 5.0073 - val_loss: 616215829.3333 - val_mean_absolute_percentage_error: 7.4514
# Epoch 991/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 269779913.3333 - mean_absolute_percentage_error: 5.0072 - val_loss: 615785998.2222 - val_mean_absolute_percentage_error: 7.4333
# Epoch 992/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 270879021.3333 - mean_absolute_percentage_error: 5.0096 - val_loss: 624604650.6667 - val_mean_absolute_percentage_error: 7.4661
# Epoch 993/1000
# 57600/57600 [==============================] - 0s 2us/step - loss: 269792233.3333 - mean_absolute_percentage_error: 5.0010 - val_loss: 639994147.5556 - val_mean_absolute_percentage_error: 7.5142
# Epoch 994/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 269210274.2222 - mean_absolute_percentage_error: 4.9984 - val_loss: 627822179.5556 - val_mean_absolute_percentage_error: 7.4555
# Epoch 995/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 269718796.0000 - mean_absolute_percentage_error: 4.9968 - val_loss: 623041720.8889 - val_mean_absolute_percentage_error: 7.4352
# Epoch 996/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 269694122.2222 - mean_absolute_percentage_error: 4.9962 - val_loss: 645521358.2222 - val_mean_absolute_percentage_error: 7.5333
# Epoch 997/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 268037641.3333 - mean_absolute_percentage_error: 4.9885 - val_loss: 632189368.8889 - val_mean_absolute_percentage_error: 7.5117
# Epoch 998/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 267467864.4444 - mean_absolute_percentage_error: 4.9874 - val_loss: 631220707.5556 - val_mean_absolute_percentage_error: 7.5169
# Epoch 999/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 266997120.8889 - mean_absolute_percentage_error: 4.9824 - val_loss: 628498133.3333 - val_mean_absolute_percentage_error: 7.5073
# Epoch 1000/1000
# 57600/57600 [==============================] - 0s 1us/step - loss: 266778632.4444 - mean_absolute_percentage_error: 4.9810 - val_loss: 656253297.7778 - val_mean_absolute_percentage_error: 7.6185

# %%
simple_model.save_weights('simple_model.h5')

# %%
vals = loss_hist.history['val_mean_absolute_percentage_error']
plt.plot(np.arange(0,len(vals)),vals,'-')
plt.show()

# %%
ys_predictions = simple_model.predict(Xs_val)
penalty(ys_val, ys_predictions).numpy()
# Out:
# 0.017518014

# %%
mape = tf.keras.losses.MeanAbsolutePercentageError()
error = mape(ys_predictions, ys_val).numpy()
error
# Out:
# 7.3917522

# %% [markdown]
# ## RUE'S CODE

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import pylab
import math

from scipy import stats

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %matplotlib inline

# %% [markdown]
# ### Linking Dataset from Google Drive

# %%
# load data into Pandas
#files = ["/content/drive/My Drive/Colab Notebooks/Sydney_Data.csv"]
csvfile = open(files[0])
sydney_df = pd.read_csv(csvfile, 
                        names = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])
sydney_df

#files = ["/content/drive/My Drive/Colab Notebooks/Adelaide_Data.csv"]
csvfile = open(files[0])
adelaide_df = pd.read_csv(csvfile, 
                        names = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])

##files = ["/content/drive/My Drive/Colab Notebooks/Perth_Data.csv"]
csvfile = open(files[0])
perth_df = pd.read_csv(csvfile, 
                        names = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])

#files = ["/content/drive/My Drive/Colab Notebooks/Tasmania_Data.csv"]
csvfile = open(files[0])
tasmania_df = pd.read_csv(csvfile, 
                        names = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-12-e5f673731a1e> in <module>
#      19
#      20 files = ["/content/drive/My Drive/Colab Notebooks/Adelaide_Data.csv"]
# ---> 21 csvfile = open(files[0])
#      22 adelaide_df = pd.read_csv(csvfile,
#      23                         names = ['X1','X2','X3','X4',
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Adelaide_Data.csv'

# %%
# set data type of data frame
sydney_df = sydney_df.astype(float)

# check for missing values (if any)
display("-"*100)
display(sydney_df.isnull().any())
display(sydney_df.head())

# %%
# check for multicollinearity
## this may be an issue since P_total is proportional to the individual Ps
# correlation matrix of data frame
corr = sydney_df.corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = "RdBu")

# %% [markdown]
# ### Multivariate Regression

# %%
# define input and output variables
X = sydney_df[['X1','X2','X3','X4','X5','X6','X7','X8',
               'X9','X10','X11','X12','X13','X14','X15','X16',
               'Y1','Y2','Y3','Y4','Y5','Y6','Y7','Y8',
               'Y9','Y10','Y11','Y12','Y13','Y14','Y15','Y16']]
Y = sydney_df[['P1','P2','P3','P4','P5','P6','P7','P8',
               'P9','P10','P11','P12','P13','P14','P15','P16','P_total']]

# split dataset into training and validation
## chose to split like Oskar w/ first 80% for training and remaining 20% for validation
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.20)

# create model
regression_model = LinearRegression()
regression_model.fit(X_train,Y_train)

# %%
# get predictions
y_predict = regression_model.predict(X_test)

# %%
# check if P_total = sum of P from 1 to 16 in prediction
# how should we penalize the mismatch of the sum?
(abs(sum(y_predict[0:15,1]) - y_predict[0,16])/y_predict[0,16])*100

# %%
# print(regression_model.coef_)
# print(regression_model.intercept_)

# %%
# this is kind of good for visualizing the coefficient matrix instead of printing it out?
sns.heatmap(np.transpose(regression_model.coef_), cmap = "RdBu")

# %% [markdown]
# ## CLAIRE'S CODE

# %% [markdown]
# #### Adelaide

# %%
# for Adelaide

adelaide_df  = adelaide_df.astype(float)
display("-"*100)
display(adelaide_df.isnull().any())

corr = adelaide_df.corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = "RdBu")

X = adelaide_df[['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','Y1','Y2','Y3','Y4','Y5','Y6','Y7','Y8', 'Y9','Y10','Y11','Y12','Y13','Y14','Y15','Y16']]
Y = adelaide_df[['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12','P13','P14','P15','P16','P_total']]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.20)

train = LinearRegression().fit(X_train,Y_train)

# print (train.score(X_train, Y_train))
# print (train.coeff_)
# print (train.intercept_)
# print (train.predict(X_test))

# %%
observed_data = np.concatenate((X_test, Y_test), axis = 1)
predicted_data = np.concatenate((X_test, train.predict(X_test)), axis = 1)

observed_df = pd.DataFrame(observed_data,
                           columns = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])
predicted_df = pd.DataFrame(predicted_data,
                            columns = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])

# plot of P_total
t = np.linspace(1325000,1500000, num = 2)
plt.scatter(predicted_df['P_total'], observed_df['P_total'], alpha = 0.3, s = 0.5)
plt.plot(t,t,'r--')
plt.show()

# plots of P1 - P16
# so the model is way better at predicting individual power outputs than the total
# (if you look at the coefficient matrix, it is assigning drastically different weights
# to the x and y coordinates even though, in theory, each WEC contributes equally to P_total)

t = np.linspace(50000,120000, num = 2)
for i in range (1,17):
  plt.subplot(4,4,i)
  plt.scatter(predicted_df['P'+str(i)], observed_df['P'+str(i)], alpha = 0.3, s = 0.5)
  plt.plot(t,t,'r--')
plt.show()

fig = plt.figure(figsize = (6, 6))
grid = plt.GridSpec(4, 4, hspace = 0.2, wspace = 0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels = [], sharey = main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels = [], sharex = main_ax)

# this plot is weird but it shows that we have a lot of data at a certain observed power output
main_ax.scatter(predicted_df['P10'], observed_df['P10'], alpha = 0.3, s = 0.5)
main_ax.plot(t,t,'r--')
x_hist.hist(predicted_df['P10'], 40, histtype = 'stepfilled', orientation = 'vertical', color = 'gray')
x_hist.invert_yaxis()
y_hist.hist(observed_df['P10'], 40, histtype = 'stepfilled', orientation = 'horizontal', color = 'gray')
y_hist.invert_xaxis()
# print(np.sqrt(metrics.mean_squared_error(train.predict(X_test), Y_train)))

# %% [markdown]
# #### Perth

# %%
perth_df  = perth_df.astype(float)
display("-"*100)
display(perth_df.isnull().any())

corr = perth_df.corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = "RdBu")

X = perth_df[['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','Y1','Y2','Y3','Y4','Y5','Y6','Y7','Y8', 'Y9','Y10','Y11','Y12','Y13','Y14','Y15','Y16']]
Y = perth_df[['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12','P13','P14','P15','P16','P_total']]


X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.20)

train = LinearRegression().fit(X_train,Y_train)

# print (train.score(X_train, Y_train))
# print (train.coeff_)
# print (train.intercept_)
# print (train.predict(X_test))

# %%
observed_data = np.concatenate((X_test, Y_test), axis = 1)
predicted_data = np.concatenate((X_test, train.predict(X_test)), axis = 1)

observed_df = pd.DataFrame(observed_data,
                           columns = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])
predicted_df = pd.DataFrame(predicted_data,
                            columns = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])

for i in range (1,17):
  plt.subplot(4,4,i)
  plt.scatter(predicted_df['P'+str(i)], observed_df['P'+str(i)], alpha = 0.3, s = 0.5)
plt.show()

plt.scatter(predicted_df['P_total'], observed_df['P_total'], alpha = 0.3, s = 0.5)
# print(np.sqrt(metrics.mean_squared_error(train.predict(X_test), Y_train)))

# %% [markdown]
# #### Tasmania

# %%
tasmania_df  = tasmania_df.astype(float)
display("-"*100)
display(perth_df.isnull().any())

corr = tasmania_df.corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = "RdBu")

X = tasmania_df[['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','Y1','Y2','Y3','Y4','Y5','Y6','Y7','Y8', 'Y9','Y10','Y11','Y12','Y13','Y14','Y15','Y16']]
Y = tasmania_df[['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12','P13','P14','P15','P16','P_total']]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.20)

train = LinearRegression().fit(X_train,Y_train)

# print (train.score(X_train, Y_train))
# print (train.coeff_)
# print (train.intercept_)
# print (train.predict(X_test))

# %%
observed_data = np.concatenate((X_test, Y_test), axis = 1)
predicted_data = np.concatenate((X_test, train.predict(X_test)), axis = 1)

observed_df = pd.DataFrame(observed_data,
                           columns = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])
predicted_df = pd.DataFrame(predicted_data,
                            columns = ['X1','X2','X3','X4',
                                 'X5','X6','X7','X8',
                                 'X9','X10','X11','X12',
                                 'X13','X14','X15','X16',
                                 'Y1','Y2','Y3','Y4',
                                 'Y5','Y6','Y7','Y8',
                                 'Y9','Y10','Y11','Y12',
                                 'Y13','Y14','Y15','Y16',
                                 'P1','P2','P3','P4',
                                 'P5','P6','P7','P8',
                                 'P9','P10','P11','P12',
                                 'P13','P14','P15','P16',
                                 'P_total'])

for i in range (1,17):
  plt.subplot(4,4,i)
  plt.scatter(predicted_df['P'+str(i)], observed_df['P'+str(i)], alpha = 0.3, s = 0.5)
plt.show()

plt.scatter(predicted_df['P_total'], observed_df['P_total'], alpha = 0.3, s = 0.5)
# print(np.sqrt(metrics.mean_squared_error(train.predict(X_test), Y_train)))
